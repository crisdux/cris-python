# %% [markdown]
# ## input()
# La función `input()` para pedirle datos de entrada a los usuarios.

# %%
nombre = input("Escriba su nombre: ")
print(nombre)

print(f"{nombre} tiene {len(nombre)} caracteres")
print(f"{nombre} empieza con {nombre[0].upper()} ")
# Out:
# cris
# cris tiene 4 caracteres
# cris empieza con C
