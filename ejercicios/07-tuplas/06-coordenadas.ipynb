# %% [markdown]
# ## Coordenadas
#
# ![image.png](attachment:image.png)

# %%
def punto_medio(coord_1, coord_2):
    x1 = coord_1[0]
    y1 = coord_1[1]

    x2 = coord_2[0]
    y2 = coord_2[1]
    return (x1 + x2)/2, (y1 + y2)/2

print(punto_medio((40,80), (50,50)))
# Out:
# (45.0, 65.0)
