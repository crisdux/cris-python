# %% [markdown]
# ## Concatenar tuplas
#
# ![image.png](attachment:image.png)

# %%
tupla_abre = ("¡",)
tupla_cierra = ("!",)

mi_tupla = input("Escribe un mensaje")
res = (tupla_abre[0], mi_tupla, tupla_cierra[0])
print(res)
print(res*3)
# Out:
# ('¡', 'Hola', '!')
# ('¡', 'Hola', '!', '¡', 'Hola', '!', '¡', 'Hola', '!')
