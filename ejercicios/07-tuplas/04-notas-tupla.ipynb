# %% [markdown]
# ## Notas tuplas
#
# ![image.png](attachment:image.png)

# %%
notas = (34,61,80,20,12,69,32,60,61,51,90,23,15)
notas_promedio = sum(notas)/ len(notas)
print(notas_promedio)

print("Aprovado" if notas_promedio >= 51 else "Reprobado")
# Out:
# 46.76923076923077
# Reprobado
