# %% [markdown]
# ## Tupla anidada
#
# ![image.png](attachment:image.png)

# %%
juan = ("Juan", 591123456, "La Paz")
pedro = ("Pedro", 591546324, "La Paz")
maria = ("Maria", 591222421, "El Alto")
sol = ("Sol", 591753159, "Oruro")

print((juan, pedro, maria, sol))
# Out:
# (('Juan', 591123456, 'La Paz'), ('Pedro', 591546324, 'La Paz'), ('Maria', 591222421, 'El Alto'), ('Sol', 591753159, 'Oruro'))
