# %% [markdown]
# ## Marvel Akinator
# Implemente un "clon" de Akinator que permita adivinar el personaje de Marvel en base a las tres preguntas siguientes:
# 1 ¿Puede volar? → Se representa por la variable de entrada: can_fly
# 2 ¿Es humano? → Se representa por la variable de entrada: is_human
# 3 ¿Tiene máscara? → Se representa por la variable de entrada: has_mask
#
# ![image.png](attachment:image.png)
#
#
# ![image-2.png](attachment:image-2.png)

# %%
def marvel_akinator(can_fly, is_human, has_mask):
    if can_fly:
        if is_human:
            if has_mask:
                return "Iron Man"
            else: 
                return "Capitan Marvel"
        else:
            if has_mask:
                return "Ronan Accuser"
            else:
                return "Vision"
    else: 
        if (is_human):
            if (has_mask):
                return "Spider Man"
            else:
                return "Hulk"
        else: 
            if(has_mask):
                return "Black Bold"
            else:
                return "Thanos"

# %%
print(marvel_akinator(True, True, True))
print(marvel_akinator(True, True, False))
print(marvel_akinator(True, False, True))
print(marvel_akinator(True, False, False))
print(marvel_akinator(False, True, True))
print(marvel_akinator(False, True, False))
print(marvel_akinator(False, False, True))
print(marvel_akinator(False, False, False))
# Out:
# Iron Man
# Capitan Marvel
# Ronan Accuser
# Vision
# Spider Man
# Hulk
# Black Bold
# Thanos
