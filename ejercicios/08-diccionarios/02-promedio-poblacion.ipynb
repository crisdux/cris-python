# %% [markdown]
# ## Promedio poblacion
# Partiendo de un diccionario de ciudades (claves) y poblaciones (valores) -suponiendo que estas ciudades son las únicas que existen en el planeta- calcule el porcentaje de población relativo de cada una de ellas con respecto al total, dando como salida un diccionario.
#
# Obtenga la media de población con una precisión de 3 decimales.
#
# ![image.png](attachment:image.png)

# %%
def promedio_poblacion(data):
    poblacion_total = 0
    res = {}
    for i in data.values():
        poblacion_total += i
    
    for ciudad, poblacion in data.items():
        res[ciudad] = round((poblacion * 100) / poblacion_total, 3 )
    return res

print(promedio_poblacion({'Tokyo': 38140000, 'Delhi': 26454000, 'Shanghai': 24484000, 'Mumbai': 21357000}))
print(promedio_poblacion({'Adeje': 49270, 'La Orotava': 42434, 'Los Silos': 4644, 'Santa Úrsula': 15361, 'Tegueste': 11359} ))
print(promedio_poblacion({'Agaete': 5633, 'Gáldar': 24567, 'Telde': 102472}))
# Out:
# {'Tokyo': 34.536, 'Delhi': 23.954, 'Shanghai': 22.171, 'Mumbai': 19.339}
# {'Adeje': 40.035, 'La Orotava': 34.48, 'Los Silos': 3.774, 'Santa Úrsula': 12.482, 'Tegueste': 9.23}
# {'Agaete': 4.246, 'Gáldar': 18.517, 'Telde': 77.237}
