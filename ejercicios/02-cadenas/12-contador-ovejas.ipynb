# %% [markdown]
# ## Contador de ovejas
# No te puedes dormir, pero afortunadamente un programa Python te ayuda a ello. Dado un número entero num_sheeps devuelve la cuenta de las ovejas...
#
# ![image.png](attachment:image.png)

# %%
def contador_ovejas(numero_ovejas):
    if(numero_ovejas == 0):
        return ""
    cadena = "sheep..."
    return f"{numero_ovejas * cadena}"

print(contador_ovejas(0))
print(contador_ovejas(3))
print(contador_ovejas(5))
print(contador_ovejas(7))
# Out:
# sheep...sheep...sheep...
# sheep...sheep...sheep...sheep...sheep...
# sheep...sheep...sheep...sheep...sheep...sheep...sheep...
