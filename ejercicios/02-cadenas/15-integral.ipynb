# %% [markdown]
# ## Encuntra la integral
# La entrada será una cadena de texto con dos números separados por una coma. El primer número es el coeficiente y el segundo número es el exponente. Por ejemplo:
#
# ```py
#  3,2 --> 3x^2
# ```
# Para obtener la integral tenemos que añadir 1 al exponente y dividir el coeficiente por dicho número. En el ejemplo anterior:
#
# ```py
#  3x^2 --> 1x^3
# ```
# NOTA: No se puede utilizar la función `split()`
#
# ![image.png](attachment:image.png)

# %%
def integral(simbolo):
    base = int(simbolo[:simbolo.find(",")])
    exponente = int(simbolo[simbolo.find(",")+1:])
    return f"{int(base / (exponente + 1))}x^{exponente+1}"

print(integral("3,2"))
print(integral("12,5"))
print(integral("20,1"))
print(integral("40,3"))
print(integral("90,2"))
# Out:
# 1x^3
# 2x^6
# 10x^2
# 10x^4
# 30x^3
