# %% [markdown]
# ## n elevado n
#  Dada una lista de números enteros positivos y un número no negativo N, calcule el valor del elemento en la posición N elevado a N
#
#  Ejemplo: [1, 2, 3, 4] y N=2, el resultado sería 3^2 = 9
#
# * Si N está fuera de rango, hay que devolver el valor -1.
# * N se representa por "power" en el parámetro de entrada.
#
#
# ![image.png](attachment:image.png)

# %%
def n_elevado_n(values, power):
    try:
        return values[power]**power
    except IndexError:
        return -1

print(n_elevado_n([1, 2, 3, 4], 2))
print(n_elevado_n([1, 2, 3], 3))
print(n_elevado_n( [10, 20, 30, 40, 50], 4))
# Out:
# 9
# -1
# 6250000
