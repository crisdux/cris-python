# %% [markdown]
# ## Donacion de sangre
# Escriba un programa que acepte edad, peso, pulso y número de plaquetas de una persona y determine si cumple con los requisitos para donar sanger.
#
# ![image.png](attachment:image.png)
#
#
# ![image-2.png](attachment:image-2.png)

# %%
def donacion(edad, peso, pulso, plaquetas):
    if((edad>=18 and edad<=65) and (peso>=50) and (pulso>=50 and pulso<=110) and (plaquetas>150_000)):
        return True
    return False

print(donacion(34,81,70,151000))
print(donacion(17,81,70,200000))
print(donacion(50,47,70,171000))
print(donacion(50,47,70,128000))
print(donacion(19,86,90,210000))
print(donacion(19,86,120,210000))
# Out:
# True
# False
# False
# False
# True
# False
