# %% [markdown]
# ## Consonates comunes
# Dadas dos cadenas de texto, obtenga una nueva cadena de texto con las letras consonantesque se repiten en ambas frases. Ignore los espacios en blanco y muestre la cadena desalida con sus letras ordenadas.
#
# Este ejercicio también se puede resolver mediante conjuntos por comprensión.
#
# * Las vocales pueden estar en minúsculas o en mayúsculas
# * Una consonante minúscula es equivalente a una consonante mayúscula.
#
# ![image.png](attachment:image.png)

# %%
def consonantes_comunes(A, B):
    conjunto_A = set(A.lower())
    conjunto_B = set(B.lower())

    res = list(conjunto_A.intersection(conjunto_B))
    res_final = []
    for letra in res:
        if letra != " " and letra not in 'aeiou':
            res_final.append(letra)
    return "".join(res_final)


print(consonantes_comunes('Flat is bEtter than nested', 'Readability counts'))
print(consonantes_comunes('Now is better thAn never', 'Beautiful is better than ugly'))
print(consonantes_comunes('Hello', 'Bye'))
# Out:
# ldrbnts
# rbnhst
