# %% [markdown]
# ## Area triangulo
# Calcule el área de un triángulo a partir de su base y su altura.
#
# ![image.png](attachment:image.png)

# %%
def area_triangulo(b, h):
    return (b*h)/2

print(area_triangulo(3, 3))
print(area_triangulo(1, 100))
print(area_triangulo(9.99, 3.11))
# Out:
# 4.5
# 50.0
# 15.53445
