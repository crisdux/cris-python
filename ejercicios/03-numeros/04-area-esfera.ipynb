# %% [markdown]
# ## Area de la esfera
# Obtenga el volumen de una esfera dado su radio. Use PI con 2 cifras decimales.
#
# ![image.png](attachment:image.png)

# %%
def area_esfera(r):
    pi = 3.14
    return 4/3 * pi * r**3

print(area_esfera(5))
print(area_esfera(15.658))
print(area_esfera(9.99))
# Out:
# 523.3333333333334
# 16072.271158372905
# 4174.11922248
